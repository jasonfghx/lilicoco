# %%
import os
import pandas as pd
import numpy  as np
import cv2

# %%
for fi in a:
    img=cv2.imread(os.path.join(base__dir, fi))
    resized_image = cv2.resize(img, (250, 250),interpolation=cv2.INTER_CUBIC) #改圖大小
    cv2.imwrite(os.path.join(base_new, fi),resized_image)

# %%
a=os.listdir("D:\\A\\123\\");
base__dir = ("D:\\A\\123\\")
base_new = ("D:\\A\\")

# %%
img = cv2.imread('D:\\下載\\ch3.JPG')

img

# %%
import os

import cv2

import numpy as np

import matplotlib.pyplot as plt



import pandas as pd


from sklearn.utils import shuffle

from sklearn.model_selection import train_test_split

# Import tensorflow as the backend for Keras

from keras import backend as K

K.set_image_dim_ordering('tf')

from keras.utils import np_utils

from keras.models import Sequential

from keras.layers.core import Dense, Dropout, Activation, Flatten

from keras.layers.convolutional import Convolution2D, MaxPooling2D

from keras.optimizers import SGD,RMSprop,adam

from keras.callbacks import TensorBoard

# Import required libraries for cnfusion matrix

from sklearn.metrics import classification_report,confusion_matrix

import itertools
# Out:
# Using TensorFlow backend.

# %%
data_dir_list = os.listdir("I:\\小組雲端硬碟\\影像辨識專題\\圖片檔\\確定使用圖片(含LABEL)")
PATH="I:\\小組雲端硬碟\\影像辨識專題\\圖片檔\\確定使用圖片(含LABEL)\\"

# %%
aaaa=data_dir_list.copy()

# %%
len(data_dir_list)
# Out:
# 257

# %%
img_data_list=[]
for data in data_dir_list:
    print(PATH + data)
    input_img=cv_imread(PATH + data )
    img_data_list.append(input_img)
# Out:
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold45.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold44.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold41.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold43.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold42.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold38.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold40.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold39.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold35.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold37.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold36.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold34.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold28.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold29.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold30.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold33.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold32.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold31.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold25.JPG
# I:\小組雲端硬碟\影像辨識專題\圖片檔\確定使用圖片(含LABEL)\fold27.JPG
# ...

# %%
img_data = np.array(img_data_list)
img_data = img_data.astype('float32')
img_data /= 255
print (img_data.shape)
# Out:
# (257, 250, 250, 3)

# %%
def cv_imread(file_path ):
    cv_img=cv2.imdecode(np.fromfile(file_path, dtype=np.uint8),-1)
    
    return cv_img

cv_imread(PATH + data)
# Out:
# array([[[173, 126,  88],
#         [174, 127,  89],
#         [153, 102,  62],
#         ...,
#         [ 47,  66,  71],
#         [ 15,  29,  35],
#         [ 11,  23,  29]],
#
#        [[177, 126,  86],
#         [165, 114,  74],
#         [143,  92,  52],
#         ...,
#         [ 70,  89,  94],
#         [ 47,  61,  67],
#         [ 13,  25,  31]],
#
#        [[193, 134,  94],
#         [182, 127,  84],
#         [147,  94,  51],
#         ...,
#         [ 46,  65,  70],
#         [ 84, 100, 106],
#         [ 34,  48,  54]],
#
#        ...,
#
#        [[161, 171, 165],
#         [149, 159, 153],
#         [148, 155, 150],
#         ...,
#         [125, 133, 133],
#         [ 74,  82,  82],
#         [ 36,  44,  44]],
#
#        [[159, 167, 160],
#         [159, 167, 160],
#         [153, 161, 154],
#         ...,
#         [ 37,  42,  43],
#         [ 33,  38,  39],
#         [ 27,  32,  33]],
#
#        [[159, 167, 160],
#         [156, 164, 157],
#         [151, 159, 152],
# ...

# %%
num_classes = 2
num_of_samples = img_data.shape[0]
labels = np.ones((num_of_samples,),dtype='int64')
for j in range(0,num_of_samples):
    if data_dir_list[j][0:2]=="fo":
        labels[j]=0
    elif data_dir_list[j][0:2]=="fa":
        labels[j]=1
Y = np_utils.to_categorical(labels, num_classes)

# %%
x,y = shuffle(img_data,Y, random_state=2)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
print("X_train shape = {}".format(X_train.shape))
print("X_test shape = {}".format(X_test.shape))
# Out:
# X_train shape = (205, 250, 250, 3)
# X_test shape = (52, 250, 250, 3)

# %%
for j in range(0,num_of_samples):
    if data_dir_list[j][0:2]=="fo":
        labels[j]=0
    elif data_dir_list[j][0:2]=="fa":
        labels[j]=1
# Out:
# 0.3333333333333333

# %%
fig = plt.figure()
image = X_train[123,:].reshape((250,250,3))
plt.axis('off')
plt.imshow(image)
plt.show()

# %%
input_shape=img_data[0].shape
# Design the CNN Sequential model
cnn_model = Sequential([
    Convolution2D(64,3,3,border_mode ='same',activation='relu',input_shape = input_shape),
    Convolution2D(32,3,3,activation='relu'),
    MaxPooling2D(pool_size=(2,2)) ,
    Dropout(0.5),
    Flatten(), 
    Dense(128,activation='relu'),
    Dropout(0.5),
    Dense(num_classes,activation = 'softmax')
])
cnn_model.compile(loss='categorical_crossentropy', optimizer='adadelta',metrics=["accuracy"])
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", input_shape=(250, 250,..., padding="same")`
#   after removing the cwd from sys.path.
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu")`
#   """

# %%
num_epoch=10
hist = cnn_model.fit(X_train, y_train, batch_size=8, nb_epoch=num_epoch, verbose=1, validation_data=(X_test, y_test))
train_loss=hist.history['loss']
val_loss=hist.history['val_loss']
train_acc=hist.history['acc']
val_acc=hist.history['val_acc']
xc=range(num_epoch)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 205 samples, validate on 52 samples
# Epoch 1/10
# 205/205 [==============================] - 104s 507ms/step - loss: 1.7562 - acc: 0.5317 - val_loss: 0.7499 - val_acc: 0.4615
# Epoch 2/10
# 205/205 [==============================] - 98s 479ms/step - loss: 1.1020 - acc: 0.5415 - val_loss: 0.6936 - val_acc: 0.4615
# Epoch 3/10
# 205/205 [==============================] - 102s 496ms/step - loss: 0.7945 - acc: 0.5707 - val_loss: 0.6756 - val_acc: 0.5385
# Epoch 4/10
# 205/205 [==============================] - 100s 489ms/step - loss: 0.8053 - acc: 0.6341 - val_loss: 1.3927 - val_acc: 0.4615
# Epoch 5/10
# 205/205 [==============================] - 94s 458ms/step - loss: 0.6905 - acc: 0.7220 - val_loss: 0.7351 - val_acc: 0.5000
# Epoch 6/10
# ...

# %%
len(X_train[120,:])
# Out:
# 250

# %%
num_classes
# Out:
# 2
